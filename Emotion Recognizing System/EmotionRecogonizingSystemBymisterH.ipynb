# %%
from deepface import DeepFace as deep
import matplotlib.pyplot as plt 
import cv2 as cv 
import os

# %%
img = cv.imread('C:/Users/MisterH/Pictures/mypic.jpg')

# %%
print("type of image is:",type(img))
# Out:
# type of image is: <class 'numpy.ndarray'>

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
result = deep.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:15<00:00,  3.77s/it]

# %%
plt.imshow(img[:,:,::-1])

# %%
print(result["gender"])
print(result["age"])
print(result["race"])
print(result["emotion"])
# Out:
# Man
# 21
# {'asian': 0.01058573616319336, 'indian': 84.75529551506042, 'black': 0.05081616109237075, 'white': 1.1715978384017944, 'middle eastern': 6.648606061935425, 'latino hispanic': 7.363102585077286}
# {'angry': 0.7659646216779947, 'disgust': 8.141662344307576e-09, 'fear': 0.10469550034031272, 'happy': 0.0038986348954495043, 'sad': 4.273058846592903, 'surprise': 0.000779391575633781, 'neutral': 94.85160708427429}
