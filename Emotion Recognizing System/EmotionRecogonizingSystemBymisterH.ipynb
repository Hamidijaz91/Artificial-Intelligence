# %%
from deepface import DeepFace as deep
import matplotlib.pyplot as plt 
import cv2 as cv 
import os

# %%
img = cv.imread('C:/Users/MisterH/Pictures/mypic.jpeg')

# %%
print("type of image is:",type(img))
# Out:
# type of image is: <class 'numpy.ndarray'>

# %%
print(img)
# Out:
# [[[ 62 109 200]
#   [ 63 110 201]
#   [ 61 111 201]
#   ...
#   [ 37  68 147]
#   [ 37  68 147]
#   [ 37  68 147]]
#
#  [[ 61 108 199]
#   [ 61 108 199]
#   [ 60 110 200]
#   ...
#   [ 37  68 147]
#   [ 36  67 146]
#   [ 36  67 146]]
#
#  [[ 59 106 197]
#   [ 60 107 198]
#   [ 59 109 199]
#   ...
#   [ 35  68 147]
#   [ 35  68 147]
#   [ 34  67 146]]
#
#  ...
#
#  [[ 68  25 160]
#   [ 69  26 161]
#   [ 70  27 162]
#   ...
#   [ 39   2 164]
#   [ 43   2 163]
#   [ 44   3 164]]
#
#  [[ 64  22 161]
#   [ 65  23 162]
#   [ 66  24 161]
#   ...
#   [ 38   1 163]
#   [ 43   2 163]
#   [ 43   2 163]]
#
#  [[ 63  20 161]
#   [ 64  21 162]
#   [ 65  23 162]
#   ...
#   [ 38   1 163]
#   [ 43   2 163]
#   [ 43   2 163]]]

# %%
result = deep.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.64s/it]

# %%
plt.imshow(img[:,:,::-1])

# %%
print(result["gender"])
print(result["age"])
print(result["race"])
print(result["emotion"])
# Out:
# Man
# 26
# {'asian': 1.8585674464702606, 'indian': 5.689216032624245, 'black': 0.7983365096151829, 'white': 33.58810544013977, 'middle eastern': 28.83654236793518, 'latino hispanic': 29.229232668876648}
# {'angry': 8.099464327096939, 'disgust': 0.00011968669468842563, 'fear': 0.9170889854431152, 'happy': 1.4390277676284313, 'sad': 11.64189800620079, 'surprise': 0.03443712485022843, 'neutral': 77.86796689033508}
